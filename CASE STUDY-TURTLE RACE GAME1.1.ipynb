# %% [markdown]
# # Turtle Race Game

# %%
import turtle,random,time

weight = 700
height =600
sc = turtle.Screen()
sc.setup(weight,height)
sc.bgcolor("Pink")

t = turtle.Turtle()
t.speed(0)

#BG2:
t.penup()
t.goto(-300,250)
t.pendown()
t.begin_fill()
t.color('pink','#9EDEBA')
for i in range(2):
    t.fd(600)
    t.rt(90)
    t.fd(500)
    t.rt(90)
t.end_fill()

#Vạch đích đen
t.hideturtle()
t.penup()
t.goto(-300,190)
t.pendown()
for j in range(10):
    t.begin_fill()
    for i in range(4):
        t.color('black','black')
        t.fd(30)
        t.rt(90)
    t.end_fill()
    t.penup()
    t.fd(60)
    t.pendown()
t.penup()
t.goto(-270,220)
t.pendown()
for j in range(10):
    t.begin_fill()
    for i in range(4):
        t.color('black','black')
        t.fd(30)
        t.rt(90)
    t.end_fill()
    t.penup()
    t.fd(60)
    t.pendown()
#vạch đích trắng
t.penup()
t.goto(-270,190)
t.pendown()
for j in range(10):
    t.begin_fill()
    for i in range(4):
        t.color('white','white')
        t.fd(30)
        t.rt(90)
    t.end_fill()
    t.penup()
    t.fd(60)
    t.pendown()
t.penup()
t.goto(-300,220)
t.pendown()
for j in range(10):
    t.begin_fill()
    for i in range(4):
        t.color('white','white')
        t.fd(30)
        t.rt(90)
    t.end_fill()
    t.penup()
    t.fd(60)
    t.pendown()

#Tiêu đề:
t.color('black')
t.penup()
t.goto(0,0)
t.lt(90)
t.fd(260)
t.write("TURTLE RACE GAME",font = ("Press Start 2P",15,"bold"),align = "center")
t.hideturtle()
#START
start = turtle.Turtle()
start.hideturtle()
start.penup()
start.color('#F20968')
start.rt(90)
start.fd(180)
start.write("---Press F to Start---",font = ("Press Start 2P",15,"bold"),align = "center")

###Rùa vàng:
vang = turtle.Turtle()
vang.color('yellow')
vang.shape('turtle')
vang.shapesize(2)
vang.penup()
vang.goto(-230,-230)
vang.lt(90)

###Rùa đỏ:
do = turtle.Turtle()
do.color('red')
do.shape('turtle')
do.shapesize(2)
do.penup()
do.goto(-138,-230)
do.lt(90)

###Rùa xanh lá:
xanhla = turtle.Turtle()
xanhla.color('green')
xanhla.shape('turtle')
xanhla.shapesize(2)
xanhla.penup()
xanhla.goto(-46,-230)
xanhla.lt(90)

###Rùa tím:
tim = turtle.Turtle()
tim.color('purple')
tim.shape('turtle')
tim.shapesize(2)
tim.penup()
tim.goto(46,-230)
tim.lt(90)

###Rùa cam:
cam = turtle.Turtle()
cam.color('orange')
cam.shape('turtle')
cam.shapesize(2)
cam.penup()
cam.goto(138,-230)
cam.lt(90)

###Rùa nâu:
nau = turtle.Turtle()
nau.color('brown')
nau.shape('turtle')
nau.shapesize(2)
nau.penup()
nau.goto(230,-230)
nau.lt(90)

#Nhập thông tin người chơi
player1 = turtle.textinput("Nhập tên người chơi 1", "Name")
if player1 != "":
    mau1 = turtle.textinput("Chọn màu rùa của bạn:","COLOR PLAYER 1:")
    tien1 = turtle.textinput("Nhập số tiền cược:","MONEY1:")
    if (tien1.isnumeric()==False) or (tien1 == None):
        tien1 = 0
    else:
        tien1 = int(tien1)
else:
    mau1,tien1="",0        
player2 = turtle.textinput("Nhập tên người chơi 2", "Name")
if player2 != "":
    mau2 = turtle.textinput("Chọn màu rùa của bạn:","COLOR PLAYER 2:")
    tien2 = turtle.textinput("Nhập số tiền cược:","MONEY2:")
    if (tien2.isnumeric()==False) or (tien2 == None):
        tien2 = 0
    else:
        tien2 = int(tien2)
else:
    mau2,tien2="",0
        
player3 = turtle.textinput("Nhập tên người chơi 3", "Name")
if player3 != "":
    mau3 = turtle.textinput("Chọn màu rùa của bạn:","COLOR PLAYER 3:")
    tien3 = turtle.textinput("Nhập số tiền cược:","MONEY3:")
    if (tien3.isnumeric()==False) or (tien3 == None):
        tien3 = 0
    else:
        tien3 = int(tien3)
else:
    mau3,tien3="",0
    
player4 = turtle.textinput("Nhập tên người chơi 4", "Name")
if player4 != "":
    mau4 = turtle.textinput("Chọn màu rùa của bạn:","COLOR PLAYER 4:")
    tien4 = turtle.textinput("Nhập số tiền cược:","MONEY4:")
    if (tien4.isnumeric()==False) or (tien4 == None):
        tien4 = 0
    else:
        tien4 = int(tien4)
else:
    mau4,tien4="",0

ten1 = turtle.Turtle()
ten1.hideturtle()
ten1.penup()
ten2 = turtle.Turtle()
ten2.hideturtle()
ten2.penup()
ten3 = turtle.Turtle()
ten3.hideturtle()
ten3.penup()
ten4 = turtle.Turtle()
ten4.hideturtle()
ten4.penup()

#người cược 1
if player1 != None or player1 != "":
    if mau1 == "Vàng":
        ten1.goto(-230,-285)
        ten1.pendown()
        ten1.write(player1,font=("Press Start 2P",10),align='center')
        ten1.penup()
    elif mau1 == "Đỏ":
        ten1.goto(-138,-285)
        ten1.pendown()
        ten1.write(player1,font=("Press Start 2P",10),align='center')
        ten1.penup()
    elif mau1 == "Lục":
        ten1.goto(-46,-285)
        ten1.pendown()
        ten1.write(player1,font=("Press Start 2P",10),align='center')
        ten1.penup()
    elif mau1 == "Tím":
        ten1.goto(46,-285)
        ten1.pendown()
        ten1.write(player1,font=("Press Start 2P",10),align='center')
        ten1.penup()
    elif mau1 == "Cam":
        ten1.goto(138,-285)
        ten1.pendown()
        ten1.write(player1,font=("Press Start 2P",10),align='center')
        ten1.penup()
    elif mau1 == "Nâu":
        ten1.goto(230,-285)
        ten1.pendown()
        ten1.write(player1,font=("Press Start 2P",10),align='center')
        ten1.penup()
#người cược 2
if player2 != None or player2 != "":
    if mau2 == "Vàng":
        ten2.goto(-230,-285)
        ten2.pendown()
        ten2.write(player2,font=("Press Start 2P",10),align='center')
        ten2.penup()
    elif mau2 == "Đỏ":
        ten2.goto(-138,-285)
        ten2.pendown()
        ten2.write(player2,font=("Press Start 2P",10),align='center')
        ten2.penup()
    elif mau2 == "Lục":
        ten2.goto(-46,-285)
        ten2.pendown()
        ten2.write(player2,font=("Press Start 2P",10),align='center')
        ten2.penup()
    elif mau2 == "Tím":
        ten2.goto(46,-285)
        ten2.pendown()
        ten2.write(player2,font=("Press Start 2P",10),align='center')
        ten2.penup()
    elif mau2 == "Cam":
        ten2.goto(138,-285)
        ten2.pendown()
        ten2.write(player2,font=("Press Start 2P",10),align='center')
        ten2.penup()
    elif mau2 == "Nâu":
        ten2.goto(230,-285)
        ten2.pendown()
        ten2.write(player2,font=("Press Start 2P",10),align='center')
        ten2.penup()
#người cược 3
if player3 != None or player3 != "":
    if mau3 == "Vàng":
        ten3.goto(-230,-285)
        ten3.pendown()
        ten3.write(player3,font=("Press Start 2P",10),align='center')
        ten3.penup()
    elif mau3 == "Đỏ":
        ten3.goto(-138,-285)
        ten3.pendown()
        ten3.write(player3,font=("Press Start 2P",10),align='center')
        ten3.penup()
    elif mau3 == "Lục":
        ten3.goto(-46,-285)
        ten3.pendown()
        ten3.write(player3,font=("Press Start 2P",10),align='center')
        ten3.penup()
    elif mau3 == "Tím":
        ten3.goto(46,-285)
        ten3.pendown()
        ten3.write(player3,font=("Press Start 2P",10),align='center')
        ten3.penup()
    elif mau3 == "Cam":
        ten3.goto(138,-285)
        ten3.pendown()
        ten3.write(player3,font=("Press Start 2P",10),align='center')
        ten3.penup()
    elif mau3 == "Nâu":
        ten3.goto(230,-285)
        ten3.pendown()
        ten3.write(player3,font=("Press Start 2P",10),align='center')
        ten3.penup()
#người cược 4
if player4 != None or player4 != "":
    if mau4 == "Vàng":
        ten4.goto(-230,-285)
        ten4.pendown()
        ten4.write(player4,font=("Press Start 2P",10),align='center')
        ten4.penup()
    elif mau4 == "Đỏ":
        ten4.goto(-138,-285)
        ten4.pendown()
        ten4.write(player4,font=("Press Start 2P",10),align='center')
        ten4.penup()
    elif mau4 == "Lục":
        ten4.goto(-46,-285)
        ten4.pendown()
        ten4.write(player4,font=("Press Start 2P",10),align='center')
        ten4.penup()
    elif mau4 == "Tím":
        ten4.goto(46,-285)
        ten4.pendown()
        ten4.write(player4,font=("Press Start 2P",10),align='center')
        ten4.penup()
    elif mau4 == "Cam":
        ten4.goto(138,-285)
        ten4.pendown()
        ten4.write(player4,font=("Press Start 2P",10),align='center')
        ten4.penup()
    elif mau4 == "Nâu":
        ten4.goto(230,-285)
        ten4.pendown()
        ten4.write(player4,font=("Press Start 2P",10),align='center')
        ten4.penup()
def zo():
    global vang,do,cam,tim,xanhla,nau,start,mau1,mau2,mau3,mau4,ten1,ten2,ten3,ten4,tien1,tien2,tien3,tien4
    start.clear()
    start.backward(105)
    #Đếm ngược 3s trước khi đua
    dem = 3
    while dem:
        mins, secs = divmod(dem,3)
        start.write(dem,font=("Press Start 2P",75),align='center')
        time.sleep(1)
        dem -= 1
        start.clear()
    start.goto(0,-180)
    TONGTIEN = str(tien1 + tien2 + tien3 + tien4)
    #Khởi động rùa
    while (vang.ycor() <= 155) and (do.ycor() <= 155) and (xanhla.ycor() <= 155) and (tim.ycor() <= 155) and (cam.ycor() <= 155) and (nau.ycor() <= 155):
        v = int(random.randint(1,8))
        vang.fd(v)
        if mau1 == "Vàng":
            ten1.clear()
            ten1.sety(ten1.ycor()+v)
            ten1.pendown()
            ten1.write(player1,font=("Press Start 2P",10),align='center')
            ten1.penup()
        elif mau2 == "Vàng":
            ten2.clear()
            ten2.sety(ten2.ycor()+v)
            ten2.pendown()
            ten2.write(player2,font=("Press Start 2P",10),align='center')
            ten2.penup()
        elif mau3 == "Vàng":
            ten3.clear()
            ten3.sety(ten3.ycor()+v)
            ten3.pendown()
            ten3.write(player3,font=("Press Start 2P",10),align='center')
            ten3.penup()
        elif mau4 == "Vàng":
            ten4.clear()
            ten4.sety(ten4.ycor()+v)
            ten4.pendown()
            ten4.write(player4,font=("Press Start 2P",10),align='center')
            ten4.penup()

        d = int(random.randint(1,8))
        do.fd(d)        
        if mau1 == "Đỏ":
            ten1.clear()
            ten1.sety(ten1.ycor()+d)
            ten1.pendown()
            ten1.write(player1,font=("Press Start 2P",10),align='center')
            ten1.penup()
        elif mau2 == "Đỏ":
            ten2.clear()
            ten2.sety(ten2.ycor()+d)
            ten2.pendown()
            ten2.write(player2,font=("Press Start 2P",10),align='center')
            ten2.penup()
        elif mau3 == "Đỏ":
            ten3.clear()
            ten3.sety(ten3.ycor()+d)
            ten3.pendown()
            ten3.write(player3,font=("Press Start 2P",10),align='center')
            ten3.penup()
        elif mau4 == "Đỏ":
            ten4.clear()
            ten4.sety(ten4.ycor()+d)
            ten4.pendown()
            ten4.write(player4,font=("Press Start 2P",10),align='center')
            ten4.penup()
            
        x = int(random.randint(1,8))
        xanhla.fd(x)
        if mau1 == "Lục":
            ten1.clear()
            ten1.sety(ten1.ycor()+x)
            ten1.pendown()
            ten1.write(player1,font=("Press Start 2P",10),align='center')
            ten1.penup()
        elif mau2 == "Lục":
            ten2.clear()
            ten2.sety(ten2.ycor()+x)
            ten2.pendown()
            ten2.write(player2,font=("Press Start 2P",10),align='center')
            ten2.penup()
        elif mau3 == "Lục":
            ten3.clear()
            ten3.sety(ten3.ycor()+x)
            ten3.pendown()
            ten3.write(player3,font=("Press Start 2P",10),align='center')
            ten3.penup()
        elif mau4 == "Lục":
            ten4.clear()
            ten4.sety(ten4.ycor()+x)
            ten4.pendown()
            ten4.write(player4,font=("Press Start 2P",10),align='center')
            ten4.penup()
        t = int(random.randint(1,8))
        tim.fd(t)
        if mau1 == "Tím":
            ten1.clear()
            ten1.sety(ten1.ycor()+t)
            ten1.pendown()
            ten1.write(player1,font=("Press Start 2P",10),align='center')
            ten1.penup()
        elif mau2 == "Tím":
            ten2.clear()
            ten2.sety(ten2.ycor()+t)
            ten2.pendown()
            ten2.write(player2,font=("Press Start 2P",10),align='center')
            ten2.penup()
        elif mau3 == "Tím":
            ten3.clear()
            ten3.sety(ten3.ycor()+t)
            ten3.pendown()
            ten3.write(player3,font=("Press Start 2P",10),align='center')
            ten3.penup()
        elif mau4 == "Tím":
            ten4.clear()
            ten4.sety(ten4.ycor()+t)
            ten4.pendown()
            ten4.write(player4,font=("Press Start 2P",10),align='center')
            ten4.penup()
            
        n = int(random.randint(1,8))
        nau.fd(n)
        if mau1 == "Nâu":
            ten1.clear()
            ten1.sety(ten1.ycor()+n)
            ten1.pendown()
            ten1.write(player1,font=("Press Start 2P",10),align='center')
            ten1.penup()
        elif mau2 == "Nâu":
            ten2.clear()
            ten2.sety(ten2.ycor()+n)
            ten2.pendown()
            ten2.write(player2,font=("Press Start 2P",10),align='center')
            ten2.penup()
        elif mau3 == "Nâu":
            ten3.clear()
            ten3.sety(ten3.ycor()+n)
            ten3.pendown()
            ten3.write(player3,font=("Press Start 2P",10),align='center')
            ten3.penup()
        elif mau4 == "Nâu":
            ten4.clear()
            ten4.sety(ten4.ycor()+n)
            ten4.pendown()
            ten4.write(player4,font=("Press Start 2P",10),align='center')
            ten4.penup()
            
        c = int(random.randint(1,8))
        cam.fd(c)
        if mau1 == "Cam":
            ten1.clear()
            ten1.sety(ten1.ycor()+c)
            ten1.pendown()
            ten1.write(player1,font=("Press Start 2P",10),align='center')
            ten1.penup()
        elif mau2 == "Cam":
            ten2.clear()
            ten2.sety(ten2.ycor()+c)
            ten2.pendown()
            ten2.write(player2,font=("Press Start 2P",10),align='center')
            ten2.penup()
        elif mau3 == "Cam":
            ten3.clear()
            ten3.sety(ten3.ycor()+c)
            ten3.pendown()
            ten3.write(player3,font=("Press Start 2P",10),align='center')
            ten3.penup()
        elif mau4 == "Cam":
            ten4.clear()
            ten4.sety(ten4.ycor()+c)
            ten4.pendown()
            ten4.write(player4,font=("Press Start 2P",10),align='center')
            ten4.penup()

    #WINNER và TIỀN CƯỢC
    if vang.ycor() > do.ycor() and vang.ycor() > xanhla.ycor() and vang.ycor() > tim.ycor() and vang.ycor() > cam.ycor() and vang.ycor() > nau.ycor():
        start.goto(0,-20)
        start.color('yellow')
        start.write("YELLOW WIN!!!",font=("Press Start 2P",25),align='center')
        start.fd(40)
        if mau1 == "Vàng":
            start.write('Congratulation: ' + player1,font=("Press Start 2P",10),align='center') 
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        elif mau2 == "Vàng":
            start.write('Congratulation: ' + player2,font=("Press Start 2P",10),align='center') 
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        elif mau3 == "Vàng":
            start.write('Congratulation: ' + player3,font=("Press Start 2P",10),align='center')
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        elif mau4 == "Vàng":
            start.write('Congratulation: ' + player4,font=("Press Start 2P",10),align='center')
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        else:
            start.write("NOBODY HAS WON :(",font=("Press Start 2P",10),align='center')
            start.fd(20)
            start.write('COMPUTER +'+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        start.fd(100)
        for i in range(361):
            if i < 360: 
                vang.lt(7)
            vang.shapesize(3)
            if i%10==0:
                vang.shapesize(2) 
    elif do.ycor() > vang.ycor() and do.ycor() > xanhla.ycor() and do.ycor() > tim.ycor() and do.ycor() > cam.ycor() and do.ycor() > nau.ycor():
        start.goto(0,-20)
        start.color('red')
        start.write("RED WIN!!!",font=("Press Start 2P",25),align='center')
        start.fd(40)
        if mau1 == "Đỏ":
            start.write('Congratulation: ' + player1,font=("Press Start 2P",10),align='center') 
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        elif mau2 == "Đỏ":
            start.write('Congratulation: ' + player2,font=("Press Start 2P",10),align='center') 
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        elif mau3 == "Đỏ":
            start.write('Congratulation: ' + player3,font=("Press Start 2P",10),align='center')
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        elif mau4 == "Đỏ":
            start.write('Congratulation: ' + player4,font=("Press Start 2P",10),align='center')
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        else:
            start.write("NOBODY HAS WON :(",font=("Press Start 2P",10),align='center')
            start.fd(20)
            start.write('COMPUTER +'+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        start.fd(100)
        for i in range(361):
            if i < 360: 
                do.lt(7)
            do.shapesize(3)
            if i%10==0:
                do.shapesize(2)
    elif xanhla.ycor() > vang.ycor() and xanhla.ycor() > do.ycor() and xanhla.ycor() > tim.ycor() and xanhla.ycor() > cam.ycor() and xanhla.ycor() > nau.ycor():
        start.goto(0,-20)
        start.color('green')
        start.write("GREEN WIN!!!",font=("Press Start 2P",25),align='center')
        start.fd(40)
        if mau1 == "Lục":
            start.write('Congratulation: ' + player1,font=("Press Start 2P",10),align='center') 
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        elif mau2 == "Lục":
            start.write('Congratulation: ' + player2,font=("Press Start 2P",10),align='center') 
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        elif mau3 == "Lục":
            start.write('Congratulation: ' + player3,font=("Press Start 2P",10),align='center')
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        elif mau4 == "Lục":
            start.write('Congratulation: ' + player4,font=("Press Start 2P",10),align='center')
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        else:
            start.write("NOBODY HAS WON :(",font=("Press Start 2P",10),align='center')
            start.fd(20)
            start.write('COMPUTER +'+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        start.fd(100)
        for i in range(361):
            if i < 360: 
                xanhla.lt(7)
            xanhla.shapesize(3)   
            if i%10==0:
                xanhla.shapesize(2) 
    elif tim.ycor() > vang.ycor() and tim.ycor() > xanhla.ycor() and tim.ycor() > do.ycor() and tim.ycor() > cam.ycor() and tim.ycor() > nau.ycor():
        start.goto(0,-20)
        start.color('purple')
        start.write("PURPLE WIN!",font=("Press Start 2P",25),align='center')   
        start.fd(40)
        if mau1 == "Tím":
            start.write('Congratulation: ' + player1,font=("Press Start 2P",10),align='center') 
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        elif mau2 == "Tím":
            start.write('Congratulation: ' + player2,font=("Press Start 2P",10),align='center') 
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        elif mau3 == "Tím":
            start.write('Congratulation: ' + player3,font=("Press Start 2P",10),align='center')
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        elif mau4 == "Tím":
            start.write('Congratulation: ' + player4,font=("Press Start 2P",10),align='center')
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        else:
            start.write("NOBODY HAS WON :(",font=("Press Start 2P",10),align='center')
            start.fd(20)
            start.write('COMPUTER +'+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        start.fd(100)
        for i in range(361):
            if i < 360: 
                tim.lt(7)
            tim.shapesize(3) 
            if i%10==0:
                tim.shapesize(2)  
    elif cam.ycor() > vang.ycor() and cam.ycor() > xanhla.ycor() and cam.ycor() > do.ycor() and cam.ycor() > tim.ycor() and cam.ycor() > nau.ycor():
        start.goto(0,-20)
        start.color('orange')
        start.write("ORANGE WIN!!!",font=("Press Start 2P",25),align='center')  
        start.fd(40)
        if mau1 == "Cam":
            start.write('Congratulation: ' + player1,font=("Press Start 2P",10),align='center')
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        elif mau2 == "Cam":
            start.write('Congratulation: ' + player2,font=("Press Start 2P",10),align='center') 
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        elif mau3 == "Cam":
            start.write('Congratulation: ' + player3,font=("Press Start 2P",10),align='center')
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        elif mau4 == "Cam":
            start.write('Congratulation: ' + player4,font=("Press Start 2P",10),align='center')
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        else:
            start.write("NOBODY HAS WON :(",font=("Press Start 2P",10),align='center')
            start.fd(20)
            start.write('COMPUTER +'+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        start.fd(100)
        for i in range(361):
            if i < 360: 
                cam.lt(7)
            cam.shapesize(3)
            if i%10==0:
                cam.shapesize(2)
    elif nau.ycor() > vang.ycor() and nau.ycor() > xanhla.ycor() and nau.ycor() > do.ycor() and nau.ycor() > cam.ycor() and nau.ycor() > tim.ycor():
        start.goto(0,-20)
        start.color('brown')
        start.write("BROWN WIN!!!",font=("Press Start 2P",25),align='center')  
        start.fd(40)
        if mau1 == "Nâu":
            start.write('Congratulation: ' + player1,font=("Press Start 2P",10),align='center') 
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        elif mau2 == "Nâu":
            start.write('Congratulation: ' + player2,font=("Press Start 2P",10),align='center') 
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        elif mau3 == "Nâu":
            start.write('Congratulation: ' + player3,font=("Press Start 2P",10),align='center')
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        elif mau4 == "Nâu":
            start.write('Congratulation: ' + player4,font=("Press Start 2P",10),align='center')
            start.fd(20)
            start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        else:
            start.write("NOBODY HAS WON :(",font=("Press Start 2P",10),align='center')
            start.fd(20)
            start.write('COMPUTER +'+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
        start.fd(100)
        for i in range(361):
            if i < 360:    
                nau.lt(7)
            nau.shapesize(3)
            if i%10==0:
                nau.shapesize(2)
    else:
        satr.pendown()
        start.goto(0,-20)
        start.write("NOBODY HAS WON!!!",font=("Press Start 2P",25),align='center')    
        start.fd(160)

    start.color('#F20968')
    start.write("Press SPACE to restart!",font = ("Press Start 2P",15,"bold"),align = "center")
def choilai():
    global vang,do,cam,tim,xanhla,nau,start,ten1,ten2,ten3,ten4,player1,player2,player3,player4,sc,mau1,mau2,mau3,mau4,tien1,tien2,tien3,tien4
    vang.hideturtle()
    do.hideturtle()
    xanhla.hideturtle()
    nau.hideturtle()
    tim.hideturtle()
    cam.hideturtle()
    start.clear()
    start.color('#F20968')
    start.write("---Press F to Start---",font = ("Press Start 2P",15,"bold"),align = "center")
    
    #Xóa thông tin người chơi
    ten1.clear()
    ten2.clear()
    ten3.clear()
    ten4.clear()
    tien1,tien2,tien3,tien4 = 0,0,0,0
    ###Rùa vàng:
    vang = turtle.Turtle()
    vang.color('yellow')
    vang.shape('turtle')
    vang.shapesize(2)
    vang.penup()
    vang.goto(-230,-230)
    vang.lt(90)

    ###Rùa đỏ:
    do = turtle.Turtle()
    do.color('red')
    do.shape('turtle')
    do.shapesize(2)
    do.penup()
    do.goto(-138,-230)
    do.lt(90)

    ###Rùa xanh lá:
    xanhla = turtle.Turtle()
    xanhla.color('green')
    xanhla.shape('turtle')
    xanhla.shapesize(2)
    xanhla.penup()
    xanhla.goto(-46,-230)
    xanhla.lt(90)

    ###Rùa tím:
    tim = turtle.Turtle()
    tim.color('purple')
    tim.shape('turtle')
    tim.shapesize(2)
    tim.penup()
    tim.goto(46,-230)
    tim.lt(90)

    ###Rùa cam:
    cam = turtle.Turtle()
    cam.color('orange')
    cam.shape('turtle')
    cam.shapesize(2)
    cam.penup()
    cam.goto(138,-230)
    cam.lt(90)

    ###Rùa nâu:
    nau = turtle.Turtle()
    nau.color('brown')
    nau.shape('turtle')
    nau.shapesize(2)
    nau.penup()
    nau.goto(230,-230)
    nau.lt(90)

    #Nhập thông tin người chơi
    player1 = turtle.textinput("Nhập tên người chơi 1", "Name")
    if player1 != "":
        mau1 = turtle.textinput("Chọn màu rùa của bạn:","COLOR PLAYER 1:")
        tien1 = turtle.textinput("Nhập số tiền cược:","MONEY1:")
        if (tien1.isnumeric()==False) or (tien1 == None):
            tien1 = 0
        else:
            tien1 = int(tien1)
    else:
        mau1,tien1="",0        
    player2 = turtle.textinput("Nhập tên người chơi 2", "Name")
    if player2 != "":
        mau2 = turtle.textinput("Chọn màu rùa của bạn:","COLOR PLAYER 2:")
        tien2 = turtle.textinput("Nhập số tiền cược:","MONEY2:")
        if (tien2.isnumeric()==False) or (tien2 == None):
            tien2 = 0
        else:
            tien2 = int(tien2)
    else:
        mau2,tien2="",0

    player3 = turtle.textinput("Nhập tên người chơi 3", "Name")
    if player3 != "":
        mau3 = turtle.textinput("Chọn màu rùa của bạn:","COLOR PLAYER 3:")
        tien3 = turtle.textinput("Nhập số tiền cược:","MONEY3:")
        if (tien3.isnumeric()==False) or (tien3 == None):
            tien3 = 0
        else:
            tien3 = int(tien3)
    else:
        mau3,tien3="",0

    player4 = turtle.textinput("Nhập tên người chơi 4", "Name")
    if player4 != "":
        mau4 = turtle.textinput("Chọn màu rùa của bạn:","COLOR PLAYER 4:")
        tien4 = turtle.textinput("Nhập số tiền cược:","MONEY4:")
        if (tien4.isnumeric()==False) or (tien4 == None):
            tien4 = 0
        else:
            tien4 = int(tien4)
    else:
        mau4,tien4="",0

    ten1 = turtle.Turtle()
    ten1.hideturtle()
    ten1.penup()
    ten2 = turtle.Turtle()
    ten2.hideturtle()
    ten2.penup()
    ten3 = turtle.Turtle()
    ten3.hideturtle()
    ten3.penup()
    ten4 = turtle.Turtle()
    ten4.hideturtle()
    ten4.penup()

    #người cược 1
    if player1 != None or player1 != "":
        if mau1 == "Vàng":
            ten1.goto(-230,-285)
            ten1.pendown()
            ten1.write(player1,font=("Press Start 2P",10),align='center')
            ten1.penup()
        elif mau1 == "Đỏ":
            ten1.goto(-138,-285)
            ten1.pendown()
            ten1.write(player1,font=("Press Start 2P",10),align='center')
            ten1.penup()
        elif mau1 == "Lục":
            ten1.goto(-46,-285)
            ten1.pendown()
            ten1.write(player1,font=("Press Start 2P",10),align='center')
            ten1.penup()
        elif mau1 == "Tím":
            ten1.goto(46,-285)
            ten1.pendown()
            ten1.write(player1,font=("Press Start 2P",10),align='center')
            ten1.penup()
        elif mau1 == "Cam":
            ten1.goto(138,-285)
            ten1.pendown()
            ten1.write(player1,font=("Press Start 2P",10),align='center')
            ten1.penup()
        elif mau1 == "Nâu":
            ten1.goto(230,-285)
            ten1.pendown()
            ten1.write(player1,font=("Press Start 2P",10),align='center')
            ten1.penup()
    #người cược 2
    if player2 != None or player2 != "":
        if mau2 == "Vàng":
            ten2.goto(-230,-285)
            ten2.pendown()
            ten2.write(player2,font=("Press Start 2P",10),align='center')
            ten2.penup()
        elif mau2 == "Đỏ":
            ten2.goto(-138,-285)
            ten2.pendown()
            ten2.write(player2,font=("Press Start 2P",10),align='center')
            ten2.penup()
        elif mau2 == "Lục":
            ten2.goto(-46,-285)
            ten2.pendown()
            ten2.write(player2,font=("Press Start 2P",10),align='center')
            ten2.penup()
        elif mau2 == "Tím":
            ten2.goto(46,-285)
            ten2.pendown()
            ten2.write(player2,font=("Press Start 2P",10),align='center')
            ten2.penup()
        elif mau2 == "Cam":
            ten2.goto(138,-285)
            ten2.pendown()
            ten2.write(player2,font=("Press Start 2P",10),align='center')
            ten2.penup()
        elif mau2 == "Nâu":
            ten2.goto(230,-285)
            ten2.pendown()
            ten2.write(player2,font=("Press Start 2P",10),align='center')
            ten2.penup()
    #người cược 3
    if player3 != None or player3 != "":
        if mau3 == "Vàng":
            ten3.goto(-230,-285)
            ten3.pendown()
            ten3.write(player3,font=("Press Start 2P",10),align='center')
            ten3.penup()
        elif mau3 == "Đỏ":
            ten3.goto(-138,-285)
            ten3.pendown()
            ten3.write(player3,font=("Press Start 2P",10),align='center')
            ten3.penup()
        elif mau3 == "Lục":
            ten3.goto(-46,-285)
            ten3.pendown()
            ten3.write(player3,font=("Press Start 2P",10),align='center')
            ten3.penup()
        elif mau3 == "Tím":
            ten3.goto(46,-285)
            ten3.pendown()
            ten3.write(player3,font=("Press Start 2P",10),align='center')
            ten3.penup()
        elif mau3 == "Cam":
            ten3.goto(138,-285)
            ten3.pendown()
            ten3.write(player3,font=("Press Start 2P",10),align='center')
            ten3.penup()
        elif mau3 == "Nâu":
            ten3.goto(230,-285)
            ten3.pendown()
            ten3.write(player3,font=("Press Start 2P",10),align='center')
            ten3.penup()
    #người cược 4
    if player4 != None or player4 != "":
        if mau4 == "Vàng":
            ten4.goto(-230,-285)
            ten4.pendown()
            ten4.write(player4,font=("Press Start 2P",10),align='center')
            ten4.penup()
        elif mau4 == "Đỏ":
            ten4.goto(-138,-285)
            ten4.pendown()
            ten4.write(player4,font=("Press Start 2P",10),align='center')
            ten4.penup()
        elif mau4 == "Lục":
            ten4.goto(-46,-285)
            ten4.pendown()
            ten4.write(player4,font=("Press Start 2P",10),align='center')
            ten4.penup()
        elif mau4 == "Tím":
            ten4.goto(46,-285)
            ten4.pendown()
            ten4.write(player4,font=("Press Start 2P",10),align='center')
            ten4.penup()
        elif mau4 == "Cam":
            ten4.goto(138,-285)
            ten4.pendown()
            ten4.write(player4,font=("Press Start 2P",10),align='center')
            ten4.penup()
        elif mau4 == "Nâu":
            ten4.goto(230,-285)
            ten4.pendown()
            ten4.write(player4,font=("Press Start 2P",10),align='center')
            ten4.penup()
    def zo():
        global vang,do,cam,tim,xanhla,nau,start,mau1,mau2,mau3,mau4,ten1,ten2,ten3,ten4,tien1,tien2,tien3,tien4
        start.clear()
        start.backward(105)
        ten1.clear()
        ten2.clear()
        ten3.clear()
        ten4.clear()
        #Đếm ngược 3s trước khi đua
        dem = 3
        while dem:
            mins, secs = divmod(dem,3)
            start.write(dem,font=("Press Start 2P",75),align='center')
            time.sleep(1)
            dem -= 1
            start.clear()
        start.goto(0,-180)
        #Khởi động rùa
        while (vang.ycor() <= 155) and (do.ycor() <= 155) and (xanhla.ycor() <= 155) and (tim.ycor() <= 155) and (cam.ycor() <= 155) and (nau.ycor() <= 155):
            v = int(random.randint(1,8))
            vang.fd(v)
            if mau1 == "Vàng":
                ten1.clear()
                ten1.sety(ten1.ycor()+v)
                ten1.pendown()
                ten1.write(player1,font=("Press Start 2P",10),align='center')
                ten1.penup()
            elif mau2 == "Vàng":
                ten2.clear()
                ten2.sety(ten2.ycor()+v)
                ten2.pendown()
                ten2.write(player2,font=("Press Start 2P",10),align='center')
                ten2.penup()
            elif mau3 == "Vàng":
                ten3.clear()
                ten3.sety(ten3.ycor()+v)
                ten3.pendown()
                ten3.write(player3,font=("Press Start 2P",10),align='center')
                ten3.penup()
            elif mau4 == "Vàng":
                ten4.clear()
                ten4.sety(ten4.ycor()+v)
                ten4.pendown()
                ten4.write(player4,font=("Press Start 2P",10),align='center')
                ten4.penup()

            d = int(random.randint(1,8))
            do.fd(d)        
            if mau1 == "Đỏ":
                ten1.clear()
                ten1.sety(ten1.ycor()+d)
                ten1.pendown()
                ten1.write(player1,font=("Press Start 2P",10),align='center')
                ten1.penup()
            elif mau2 == "Đỏ":
                ten2.clear()
                ten2.sety(ten2.ycor()+d)
                ten2.pendown()
                ten2.write(player2,font=("Press Start 2P",10),align='center')
                ten2.penup()
            elif mau3 == "Đỏ":
                ten3.clear()
                ten3.sety(ten3.ycor()+d)
                ten3.pendown()
                ten3.write(player3,font=("Press Start 2P",10),align='center')
                ten3.penup()
            elif mau4 == "Đỏ":
                ten4.clear()
                ten4.sety(ten4.ycor()+d)
                ten4.pendown()
                ten4.write(player4,font=("Press Start 2P",10),align='center')
                ten4.penup()

            x = int(random.randint(1,8))
            xanhla.fd(x)
            if mau1 == "Lục":
                ten1.clear()
                ten1.sety(ten1.ycor()+x)
                ten1.pendown()
                ten1.write(player1,font=("Press Start 2P",10),align='center')
                ten1.penup()
            elif mau2 == "Lục":
                ten2.clear()
                ten2.sety(ten2.ycor()+x)
                ten2.pendown()
                ten2.write(player2,font=("Press Start 2P",10),align='center')
                ten2.penup()
            elif mau3 == "Lục":
                ten3.clear()
                ten3.sety(ten3.ycor()+x)
                ten3.pendown()
                ten3.write(player3,font=("Press Start 2P",10),align='center')
                ten3.penup()
            elif mau4 == "Lục":
                ten4.clear()
                ten4.sety(ten4.ycor()+x)
                ten4.pendown()
                ten4.write(player4,font=("Press Start 2P",10),align='center')
                ten4.penup()
            t = int(random.randint(1,8))
            tim.fd(t)
            if mau1 == "Tím":
                ten1.clear()
                ten1.sety(ten1.ycor()+t)
                ten1.pendown()
                ten1.write(player1,font=("Press Start 2P",10),align='center')
                ten1.penup()
            elif mau2 == "Tím":
                ten2.clear()
                ten2.sety(ten2.ycor()+t)
                ten2.pendown()
                ten2.write(player2,font=("Press Start 2P",10),align='center')
                ten2.penup()
            elif mau3 == "Tím":
                ten3.clear()
                ten3.sety(ten3.ycor()+t)
                ten3.pendown()
                ten3.write(player3,font=("Press Start 2P",10),align='center')
                ten3.penup()
            elif mau4 == "Tím":
                ten4.clear()
                ten4.sety(ten4.ycor()+t)
                ten4.pendown()
                ten4.write(player4,font=("Press Start 2P",10),align='center')
                ten4.penup()

            n = int(random.randint(1,8))
            nau.fd(n)
            if mau1 == "Nâu":
                ten1.clear()
                ten1.sety(ten1.ycor()+n)
                ten1.pendown()
                ten1.write(player1,font=("Press Start 2P",10),align='center')
                ten1.penup()
            elif mau2 == "Nâu":
                ten2.clear()
                ten2.sety(ten2.ycor()+n)
                ten2.pendown()
                ten2.write(player2,font=("Press Start 2P",10),align='center')
                ten2.penup()
            elif mau3 == "Nâu":
                ten3.clear()
                ten3.sety(ten3.ycor()+n)
                ten3.pendown()
                ten3.write(player3,font=("Press Start 2P",10),align='center')
                ten3.penup()
            elif mau4 == "Nâu":
                ten4.clear()
                ten4.sety(ten4.ycor()+n)
                ten4.pendown()
                ten4.write(player4,font=("Press Start 2P",10),align='center')
                ten4.penup()

            c = int(random.randint(1,8))
            cam.fd(c)
            if mau1 == "Cam":
                ten1.clear()
                ten1.sety(ten1.ycor()+c)
                ten1.pendown()
                ten1.write(player1,font=("Press Start 2P",10),align='center')
                ten1.penup()
            elif mau2 == "Cam":
                ten2.clear()
                ten2.sety(ten2.ycor()+c)
                ten2.pendown()
                ten2.write(player2,font=("Press Start 2P",10),align='center')
                ten2.penup()
            elif mau3 == "Cam":
                ten3.clear()
                ten3.sety(ten3.ycor()+c)
                ten3.pendown()
                ten3.write(player3,font=("Press Start 2P",10),align='center')
                ten3.penup()
            elif mau4 == "Cam":
                ten4.clear()
                ten4.sety(ten4.ycor()+c)
                ten4.pendown()
                ten4.write(player4,font=("Press Start 2P",10),align='center')
                ten4.penup()


        #WINNER và TIỀN CƯỢC
        TONGTIEN = str(tien1 + tien2 + tien3 + tien4)
        if vang.ycor() > do.ycor() and vang.ycor() > xanhla.ycor() and vang.ycor() > tim.ycor() and vang.ycor() > cam.ycor() and vang.ycor() > nau.ycor():
            start.goto(0,-20)
            start.color('yellow')
            start.write("YELLOW WIN!!!",font=("Press Start 2P",25),align='center')
            start.fd(40)
            if mau1 == "Vàng":
                start.write('Congratulation: ' + player1,font=("Press Start 2P",10),align='center') 
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            elif mau2 == "Vàng":
                start.write('Congratulation: ' + player2,font=("Press Start 2P",10),align='center') 
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            elif mau3 == "Vàng":
                start.write('Congratulation: ' + player3,font=("Press Start 2P",10),align='center')
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            elif mau4 == "Vàng":
                start.write('Congratulation: ' + player4,font=("Press Start 2P",10),align='center')
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            else:
                start.write("NOBODY HAS WON :(",font=("Press Start 2P",10),align='center')
                start.fd(20)
                start.write('COMPUTER +'+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            start.fd(100)
            for i in range(361):
                if i < 360: 
                    vang.lt(7)
                vang.shapesize(3)
                if i%10==0:
                    vang.shapesize(2) 
        elif do.ycor() > vang.ycor() and do.ycor() > xanhla.ycor() and do.ycor() > tim.ycor() and do.ycor() > cam.ycor() and do.ycor() > nau.ycor():
            start.goto(0,-20)
            start.color('red')
            start.write("RED WIN!!!",font=("Press Start 2P",25),align='center')
            start.fd(40)
            if mau1 == "Đỏ":
                start.write('Congratulation: ' + player1,font=("Press Start 2P",10),align='center') 
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            elif mau2 == "Đỏ":
                start.write('Congratulation: ' + player2,font=("Press Start 2P",10),align='center') 
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            elif mau3 == "Đỏ":
                start.write('Congratulation: ' + player3,font=("Press Start 2P",10),align='center')
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            elif mau4 == "Đỏ":
                start.write('Congratulation: ' + player4,font=("Press Start 2P",10),align='center')
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            else:
                start.write("NOBODY HAS WON :(",font=("Press Start 2P",10),align='center')
                start.fd(20)
                start.write('COMPUTER +'+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            start.fd(100)
            for i in range(361):
                if i < 360: 
                    do.lt(7)
                do.shapesize(3)
                if i%10==0:
                    do.shapesize(2)
        elif xanhla.ycor() > vang.ycor() and xanhla.ycor() > do.ycor() and xanhla.ycor() > tim.ycor() and xanhla.ycor() > cam.ycor() and xanhla.ycor() > nau.ycor():
            start.goto(0,-20)
            start.color('green')
            start.write("GREEN WIN!!!",font=("Press Start 2P",25),align='center')
            start.fd(40)
            if mau1 == "Lục":
                start.write('Congratulation: ' + player1,font=("Press Start 2P",10),align='center') 
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            elif mau2 == "Lục":
                start.write('Congratulation: ' + player2,font=("Press Start 2P",10),align='center') 
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            elif mau3 == "Lục":
                start.write('Congratulation: ' + player3,font=("Press Start 2P",10),align='center')
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            elif mau4 == "Lục":
                start.write('Congratulation: ' + player4,font=("Press Start 2P",10),align='center')
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            else:
                start.write("NOBODY HAS WON :(",font=("Press Start 2P",10),align='center')
                start.fd(20)
                start.write('COMPUTER +'+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            start.fd(100)
            for i in range(361):
                if i < 360: 
                    xanhla.lt(7)
                xanhla.shapesize(3)   
                if i%10==0:
                    xanhla.shapesize(2) 
        elif tim.ycor() > vang.ycor() and tim.ycor() > xanhla.ycor() and tim.ycor() > do.ycor() and tim.ycor() > cam.ycor() and tim.ycor() > nau.ycor():
            start.goto(0,-20)
            start.color('purple')
            start.write("PURPLE WIN!",font=("Press Start 2P",25),align='center')   
            start.fd(40)
            if mau1 == "Tím":
                start.write('Congratulation: ' + player1,font=("Press Start 2P",10),align='center') 
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            elif mau2 == "Tím":
                start.write('Congratulation: ' + player2,font=("Press Start 2P",10),align='center') 
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            elif mau3 == "Tím":
                start.write('Congratulation: ' + player3,font=("Press Start 2P",10),align='center')
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            elif mau4 == "Tím":
                start.write('Congratulation: ' + player4,font=("Press Start 2P",10),align='center')
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            else:
                start.write("NOBODY HAS WON :(",font=("Press Start 2P",10),align='center')
                start.fd(20)
                start.write('COMPUTER +'+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            start.fd(100)
            for i in range(361):
                if i < 360: 
                    tim.lt(7)
                tim.shapesize(3) 
                if i%10==0:
                    tim.shapesize(2)  
        elif cam.ycor() > vang.ycor() and cam.ycor() > xanhla.ycor() and cam.ycor() > do.ycor() and cam.ycor() > tim.ycor() and cam.ycor() > nau.ycor():
            start.goto(0,-20)
            start.color('orange')
            start.write("ORANGE WIN!!!",font=("Press Start 2P",25),align='center')  
            start.fd(40)
            if mau1 == "Cam":
                start.write('Congratulation: ' + player1,font=("Press Start 2P",10),align='center')
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            elif mau2 == "Cam":
                start.write('Congratulation: ' + player2,font=("Press Start 2P",10),align='center') 
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            elif mau3 == "Cam":
                start.write('Congratulation: ' + player3,font=("Press Start 2P",10),align='center')
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            elif mau4 == "Cam":
                start.write('Congratulation: ' + player4,font=("Press Start 2P",10),align='center')
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            else:
                start.write("NOBODY HAS WON :(",font=("Press Start 2P",10),align='center')
                start.fd(20)
                start.write('COMPUTER +'+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            start.fd(100)
            for i in range(361):
                if i < 360: 
                    cam.lt(7)
                cam.shapesize(3)
                if i%10==0:
                    cam.shapesize(2)
        elif nau.ycor() > vang.ycor() and nau.ycor() > xanhla.ycor() and nau.ycor() > do.ycor() and nau.ycor() > cam.ycor() and nau.ycor() > tim.ycor():
            start.goto(0,-20)
            start.color('brown')
            start.write("BROWN WIN!!!",font=("Press Start 2P",25),align='center')  
            start.fd(40)
            if mau1 == "Nâu":
                start.write('Congratulation: ' + player1,font=("Press Start 2P",10),align='center') 
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            elif mau2 == "Nâu":
                start.write('Congratulation: ' + player2,font=("Press Start 2P",10),align='center') 
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            elif mau3 == "Nâu":
                start.write('Congratulation: ' + player3,font=("Press Start 2P",10),align='center')
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            elif mau4 == "Nâu":
                start.write('Congratulation: ' + player4,font=("Press Start 2P",10),align='center')
                start.fd(20)
                start.write('WIN '+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            else:
                start.write("NOBODY HAS WON :(",font=("Press Start 2P",10),align='center')
                start.fd(20)
                start.write('COMPUTER +'+TONGTIEN+'$',font=("Press Start 2P",7),align='center')
            start.fd(100)
            for i in range(361):
                if i < 360:    
                    nau.lt(7)
                nau.shapesize(3)
                if i%10==0:
                    nau.shapesize(2)
        else:
            satr.pendown()
            start.goto(0,-20)
            start.write("NOBODY HAS WON!!!",font=("Press Start 2P",25),align='center')    
            start.fd(160)

        start.color('#F20968')
        start.write("Press SPACE to restart!",font = ("Press Start 2P",15,"bold"),align = "center") 
    sc.listen()
sc.listen()
sc.onkey(zo,"f")
sc.onkey(choilai,"space")

sc.mainloop()
